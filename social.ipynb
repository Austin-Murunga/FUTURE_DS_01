# %%
#import necessesary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the csv
data = pd.read_csv('D:\SOCIAL MEDIA TREND ANALYSIS\sentimentdataset.csv')
#overvie
data
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             0             0
# 1             1             1
# 2             2             2
# 3             3             3
# 4             4             4
# ..          ...           ...
# 727         728           732
# 728         729           733
# 729         730           734
# 730         731           735
# 731         732           736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
#head
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
#tail
data.tail()
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 727         728           732
# 728         729           733
# 729         730           734
# 730         731           735
# 731         732           736
#
#                                                   Text Sentiment  \
# 727  Collaborating on a science project that receiv...    Happy
# 728  Attending a surprise birthday party organized ...    Happy
# 729  Successfully fundraising for a school charity ...    Happy
# 730  Participating in a multicultural festival, cel...    Happy
# 731  Organizing a virtual talent show during challe...    Happy
#
#                Timestamp                                   User     Platform  \
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# ...

# %%
#basic information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    732 non-null    int64
#  1   Unnamed: 0.1  732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
#description 
data.describe()
# Out:
#        Unnamed: 0  Unnamed: 0.1    Retweets       Likes         Year  \
# count  732.000000    732.000000  732.000000  732.000000   732.000000
# mean   366.464481    369.740437   21.508197   42.901639  2020.471311
# std    211.513936    212.428936    7.061286   14.089848     2.802285
# min      0.000000      0.000000    5.000000   10.000000  2010.000000
# 25%    183.750000    185.750000   17.750000   34.750000  2019.000000
# 50%    366.500000    370.500000   22.000000   43.000000  2021.000000
# 75%    549.250000    553.250000   25.000000   50.000000  2023.000000
# max    732.000000    736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
data.describe(include='all')
# Out:
#         Unnamed: 0  Unnamed: 0.1  \
# count   732.000000    732.000000
# unique         NaN           NaN
# top            NaN           NaN
# freq           NaN           NaN
# mean    366.464481    369.740437
# std     211.513936    212.428936
# min       0.000000      0.000000
# 25%     183.750000    185.750000
# 50%     366.500000    370.500000
# 75%     549.250000    553.250000
# max     732.000000    736.000000
#
#                                                      Text    Sentiment  \
# count                                                 732          732
# unique                                                707          279
# top      Proudly scaling the peaks of achievement, a m...   Positive
# freq                                                    3           44
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# ...

# %%
#checking for missing values
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %% [markdown]
# All columns have 0 missing values. This means that every row in the dataset has complete data for all the columns (i.e., there are no null or missing entries in any column).

# %%
#head 
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
#drop redudant column
cols_to_drop = ['Unnamed: 0.1', 'Unnamed: 0']
data = data.drop(columns=cols_to_drop)

#head 
data.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       732 non-null    object
#  1   Sentiment  732 non-null    object
#  2   Timestamp  732 non-null    object
#  3   User       732 non-null    object
#  4   Platform   732 non-null    object
#  5   Hashtags   732 non-null    object
#  6   Retweets   732 non-null    float64
#  7   Likes      732 non-null    float64
#  8   Country    732 non-null    object
#  9   Year       732 non-null    int64
#  10  Month      732 non-null    int64
#  11  Day        732 non-null    int64
#  12  Hour       732 non-null    int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 74.5+ KB

# %%
#check for platform distribution 
Platform_distr = data['Platform'].value_counts()
Platform_distr
# Out:
#  Instagram     258
#  Facebook      231
#  Twitter       128
#  Twitter       115
# Name: Platform, dtype: int64

# %%
#mapping month numbers to uppercase month names
month_mapping = {
    1: 'JAN', 2: 'FEB', 3: 'MAR', 4: 'APR',
    5: 'MAY', 6: 'JUN', 7: 'JUL', 8: 'AUG',
    9: 'SEP', 10: 'OCT', 11: 'NOV', 12: 'DEC'
}

#replace month numbers with their corresponding names
data['Month']  =data['Month'].map(month_mapping)

# %%
# Normalize the Platform column
data['Platform'] = data['Platform'].str.strip().str.lower()

# %%
# Clean the 'Country' column to remove extra spaces and unify case
data['Country'] = data['Country'].str.strip().str.upper()

# %% [markdown]
# Exploring the data

# %%
#checking the distribution of entries on the 'Sentiment' column
sentiment_distribution = data['Sentiment'].value_counts()
sentiment_distribution
# Out:
#  Positive         44
#  Joy              42
#  Excitement       32
#  Contentment      14
#  Happy            14
#                   ..
#  Hypnotic          1
#  Indifference      1
#  Suffering         1
#  Charm             1
#  Vibrancy          1
# Name: Sentiment, Length: 279, dtype: int64

# %%
# Calculate sentiment counts
sentiment_counts = data['Sentiment'].value_counts().head(10)

# Plot the counts
plt.figure(figsize=(10, 6))
bars = sentiment_counts.plot(kind='bar', color='skyblue', alpha=0.8)

# Add annotations for counts
for index, value in enumerate(sentiment_counts):
    plt.text(index, value, f'{value}', ha='center', va='bottom', fontsize=10)

plt.title('Top 10 Sentiments by Frequency')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Select only numeric columns for summation
if 'Sentiment' in data.columns:
    numeric_data = data.select_dtypes(include=['number'])  # Select numeric columns
    sentiment_sums = data.groupby('Sentiment')[numeric_data.columns].sum()  # Group and sum numeric data

    # Sorting by the total sum of all numeric metrics
    top_10_sentiments = sentiment_sums.sum(axis=1).sort_values(ascending=False).head(10)

    # Plotting the top 10 sentiments
    plt.figure(figsize=(10, 6))
    bars = top_10_sentiments.plot(kind='bar', color='skyblue', alpha=0.8)

    # Adding exact numbers at the top of each bar
    for index, value in enumerate(top_10_sentiments):
        plt.text(index, value, f'{value:.0f}', ha='center', va='bottom', fontsize=10)

    plt.title('Top 10 Sentiments by Total Sum of Numeric Metrics')
    plt.xlabel('Sentiment')
    plt.ylabel('Total Sum of Metrics')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("'Sentiment' column not found in the dataset.")

# %%
#checking the distribution of entries on the 'User' column
User_distribution = data['User'].value_counts()
User_distribution
# Out:
#  DawnGardener                     3
#  PeakConqueror                    3
#  CarnivalDreamer                  3
#  WindWhisperer                    3
#  RainNurturer                     3
#                                  ..
#  KindnessInAction                 1
#  GunsNRosesRiffRockstar           1
#  TimeCapsuleCreatorHighSchool     1
#  KeukenhofAdventurer              1
#  HelperHeart                      1
# Name: User, Length: 685, dtype: int64

# %%
#check for platform distribution 
Platform_distr = data['Platform'].value_counts()
Platform_distr
# Out:
# instagram    258
# twitter      243
# facebook     231
# Name: Platform, dtype: int64

# %%
# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(
    Platform_distr,
    labels=Platform_distr.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=['skyblue', 'lightgreen', 'salmon'],
    explode=(0.1, 0.1, 0.1),  # Highlight the largest slice
    shadow=True
)
plt.title('Platform Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt

# Top 10 Sentiments
top_10_sentiments = data['Sentiment'].value_counts().head(10).index

# Filter data for top 10 sentiments
filtered_data = data[data['Sentiment'].isin(top_10_sentiments)]

# Grouping by Sentiment and Platform
sentiment_platform_dist = filtered_data.groupby(['Sentiment', 'Platform']).size().unstack(fill_value=0)

# Plotting the grouped bar chart
sentiment_platform_dist.plot(
    kind='bar',
    figsize=(12, 8),
    colormap='Set2',
    edgecolor='black'
)
plt.title('Distribution of Top 10 Sentiments Across Platforms')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Platform')
plt.tight_layout()
plt.show()

# %%
data
# Out:
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# 728  Attending a surprise birthday party organized ...       Happy
# 729  Successfully fundraising for a school charity ...       Happy
# 730  Participating in a multicultural festival, cel...       Happy
# 731  Organizing a virtual talent show during challe...       Happy
#
#                Timestamp                                   User   Platform  \
# 0    2023-01-15 12:30:00                          User123          twitter
# ...

# %%
#check for Country distribution 
Country_distr = data['Country'].value_counts()
Country_distr
# Out:
# USA               188
# UK                143
# CANADA            135
# AUSTRALIA          75
# INDIA              70
# BRAZIL             17
# FRANCE             16
# JAPAN              15
# GERMANY            14
# ITALY              11
# SPAIN               6
# SOUTH AFRICA        6
# GREECE              5
# NETHERLANDS         4
# SWITZERLAND         3
# SWEDEN              2
# CZECH REPUBLIC      2
# PORTUGAL            2
# DENMARK             2
# AUSTRIA             2
# BELGIUM             2
# SCOTLAND            1
# IRELAND             1
# NORWAY              1
# JORDAN              1
# COLOMBIA            1
# KENYA               1
# CHINA               1
# PERU                1
# CAMBODIA            1
# MALDIVES            1
# THAILAND            1
# JAMAICA             1
# Name: Country, dtype: int64

# %%
#check for Month distribution 
Month_distr = data['Month'].value_counts()
Month_distr
# Out:
# FEB    85
# JAN    82
# AUG    78
# SEP    77
# JUN    71
# JUL    62
# APR    51
# NOV    49
# OCT    48
# MAY    46
# MAR    44
# DEC    39
# Name: Month, dtype: int64
